# %%
a=[1,2,3]
a
# Out:
# [1, 2, 3]

# %%
#we assign a to b
b=a
b
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
import pandas as pd
#saple data
data={
    'Student':['A','B','C','D','E'],
    'Math_Score':[85,78,92,88,76],
    'English_Score':[78,74,88,82,70],
    'Study_Hours':[15,12,18,17,11],
    'Grad_Level':['Sophomore','Sophomore','Junior','Junior','Senior']
}
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 #saple data
#       3 data={
#       4     'Student':['A','B','C','D','E'],
#       5     'Math_Score':[85,78,92,88,76],
#    (...)      8     'Grad_Level':['Sophomore','Sophomore','Junior','Junior','Senior']
#       9 }
#
# ModuleNotFoundError: No module named 'pandas'
